# %%
! pip install youtube-transcript-api
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import numpy as np

# %%
from youtube_transcript_api import YouTubeTranscriptApi

# %%
# This Id needs to be changed based on the Youtube Video
video_id = '0lmQEo3NIJ4'
transcript = YouTubeTranscriptApi.get_transcript(video_id)
transcript
# Out:
# [{'text': '[Music]', 'start': 10.71, 'duration': 3.079},
#  {'text': 'hi everyone welcome to this artificial',
#   'start': 17.6,
#   'duration': 4.24},
#  {'text': 'intelligence 2022 full course video by',
#   'start': 19.84,
#   'duration': 3.199},
#  {'text': 'simplyloan', 'start': 21.84, 'duration': 3.04},
#  {'text': 'artificial intelligence applications are',
#   'start': 23.039,
#   'duration': 3.841},
#  {'text': 'being widely used in various fields to',
#   'start': 24.88,
#   'duration': 4.479},
#  {'text': 'solve business problems in this video',
#   'start': 26.88,
#   'duration': 4.159},
#  {'text': 'you will learn the important skills that',
#   'start': 29.359,
#   'duration': 3.281},
#  {'text': 'will help you understand ai and its',
#   'start': 31.039,
#   'duration': 3.281},
#  {'text': 'implementation better', 'start': 32.64, 'duration': 3.52},
#  {'text': 'our highly proficient trainers will take',
#   'start': 34.32,
#   'duration': 3.52},
# ...

# %%
yt_transcript = []
for i in transcript:
  transcript = i['text']
  yt_transcript.append(transcript)

# %%
ai_transcript = open("0lmQEo3NIJ4-Artificial Intelligence Full Course.txt","w")
ai_transcript.writelines(yt_transcript)
